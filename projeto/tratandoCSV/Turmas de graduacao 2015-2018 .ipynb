# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Importa turmas ingressantes de 2017 a 2015
url_ingressantes2017_1 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/5e77d066-d506-45eb-a21e-76aa79616fef/download/turmas-2017.1'
url_ingressantes2017_2 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/01fe7343-fdf0-4a67-b915-2386b7c2fecb/download/turmas-2017.2'
url_ingressantes2016_1 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/322d9977-ba15-47f1-8216-75a1ca78e197/download/turmas-2016.1.csv'
url_ingressantes2016_2 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/5e8e3228-7f22-40a2-9efd-561c44844567/download/turmas-2016.2.csv'
url_ingressantes2015_1 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/4d5aee5a-00b0-4ed6-a4be-59fa77a56797/download/turmas-2015.1.csv'
url_ingressantes2015_2 = 'http://dados.ufrn.br/dataset/1938623d-fb07-41a4-a55a-1691f7c3b8b5/resource/7c59621c-4a8b-49d4-b319-83cfea9bdf28/download/turmas-2015.2.csv'

#Cria dataframe com as turmas importadas
df_ingressantes2017_1 = pd.read_csv(url_ingressantes2017_1, sep=';')
df_ingressantes2017_2 = pd.read_csv(url_ingressantes2017_2, sep=';')
df_ingressantes2016_1 = pd.read_csv(url_ingressantes2016_1, sep=';')
df_ingressantes2016_2 = pd.read_csv(url_ingressantes2016_2, sep=';')
df_ingressantes2015_1 = pd.read_csv(url_ingressantes2015_1, sep=';')
df_ingressantes2015_2 = pd.read_csv(url_ingressantes2015_2, sep=';')

# %%
#Inserindo dados em uma lista
ingressantes = []

for i in range(15,18):
    for j in range (1,2):
        ingressantes.append(vars()['df_ingressantes20%d_%d' % (i, j)])

# %%
# concatenando todas as listas em um dataframe
df_ingressantes = pd.concat(ingressantes)

# limpandos os index após o merge
df_ingressantes.reset_index(drop=True,inplace=True)

# %%
# verificando inicialmente os dados importados
df_ingressantes.tail()
# Out:
#        id_turma codigo_turma  id_docente_interno  id_docente_externo  \
# 43161  57612971           01                 NaN         109527932.0
# 43162  57613796           01                 NaN         119896305.0
# 43163  57613796           01                 NaN         101052958.0
# 43164  57613798           02                 NaN         101052958.0
# 43165  57613798           02                 NaN         119896305.0
#
#       observacao  id_componente_curricular           nivel_ensino  \
# 43161        NaN                     57952                TÉCNICO
# 43162        NaN                     66448  FORMAÇÃO COMPLEMENTAR
# 43163        NaN                     66448  FORMAÇÃO COMPLEMENTAR
# 43164        NaN                     66448  FORMAÇÃO COMPLEMENTAR
# 43165        NaN                     66448  FORMAÇÃO COMPLEMENTAR
#
#       campus_turma    local   ano     ...         tipo distancia  \
# 43161          NaN  MACAÍBA  2017     ...      REGULAR         f
# 43162          NaN      NaN  2017     ...      REGULAR         t
# 43163          NaN      NaN  2017     ...      REGULAR         t
# 43164          NaN      NaN  2017     ...      REGULAR         t
# 43165          NaN      NaN  2017     ...      REGULAR         t
#
#              data_consolidacao agrupadora  id_turma_agrupadora  \
# 43161  2018-01-26 14:05:35.037          f                  NaN
# 43162                      NaN          f                  NaN
# 43163                      NaN          f                  NaN
# 43164                      NaN          f                  NaN
# 43165                      NaN          f                  NaN
#
#        qtd_aulas_lancadas situacao_turma convenio modalidade_participantes  \
# 43161                 0.0    CONSOLIDADA      NaN               Presencial
# 43162                 NaN         ABERTA      NaN              A Distância
# 43163                 NaN         ABERTA      NaN              A Distância
# 43164                 NaN         ABERTA      NaN              A Distância
# 43165                 NaN         ABERTA      NaN              A Distância
#
#       Unnamed: 25
# 43161         NaN
# 43162         NaN
# 43163         NaN
# 43164         NaN
# 43165         NaN
#
# [5 rows x 26 columns]

# %%
# tamanho dos dados
print(df_ingressantes.shape)

# colunas do dataset
print(df_ingressantes.columns)
# Out:
# (43166, 26)
# Index(['id_turma', 'codigo_turma', 'id_docente_interno', 'id_docente_externo',
#        'observacao', 'id_componente_curricular', 'nivel_ensino',
#        'campus_turma', 'local', 'ano', 'periodo', 'data_inicio', 'data_fim',
#        'descricao_horario', 'total_solicitacoes', 'capacidade_aluno', 'tipo',
#        'distancia', 'data_consolidacao', 'agrupadora', 'id_turma_agrupadora',
#        'qtd_aulas_lancadas', 'situacao_turma', 'convenio',
#        'modalidade_participantes', 'Unnamed: 25'],
#       dtype='object')

# %%
# investigando o dataset
df_ingressantes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43166 entries, 0 to 43165
# Data columns (total 26 columns):
# id_turma                    43166 non-null int64
# codigo_turma                43166 non-null object
# id_docente_interno          41051 non-null float64
# id_docente_externo          2115 non-null float64
# observacao                  1713 non-null object
# id_componente_curricular    43166 non-null int64
# nivel_ensino                43166 non-null object
# campus_turma                31327 non-null object
# local                       42541 non-null object
# ano                         43166 non-null int64
# periodo                     43166 non-null int64
# data_inicio                 43166 non-null object
# data_fim                    43166 non-null object
# descricao_horario           40231 non-null object
# total_solicitacoes          37332 non-null float64
# capacidade_aluno            41290 non-null float64
# tipo                        43166 non-null object
# distancia                   43166 non-null object
# data_consolidacao           40475 non-null object
# agrupadora                  43166 non-null object
# id_turma_agrupadora         2630 non-null float64
# qtd_aulas_lancadas          40475 non-null float64
# situacao_turma              43166 non-null object
# convenio                    0 non-null float64
# modalidade_participantes    43166 non-null object
# Unnamed: 25                 0 non-null float64
# dtypes: float64(8), int64(4), object(14)
# memory usage: 8.6+ MB

# %%
# niveis de ensino
df_ingressantes.nivel_ensino.unique()
# Out:
# array(['LATO SENSU', 'TÉCNICO', 'GRADUAÇÃO', 'STRICTO SENSU',
#        'RESIDÊNCIA', 'FORMAÇÃO COMPLEMENTAR'], dtype=object)

# %%
# filtrando apenas os alunos da graduação
graduacao = df_ingressantes[df_ingressantes.nivel_ensino == 'GRADUAÇÃO']
graduacao.reset_index(drop=True, inplace=True)
graduacao.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0   1239272           01           5756213.0                 NaN        NaN
# 1   1239275           01           5757161.0                 NaN        NaN
# 2   1239275           01           1574976.0                 NaN        NaN
# 3   1239275           01             22932.0                 NaN        NaN
# 4   1239276           01           5752774.0                 NaN        NaN
#
#    id_componente_curricular nivel_ensino    campus_turma          local   ano  \
# 0                     52656    GRADUAÇÃO  Campus Central   B203 no CIVT  2015
# 1                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 2                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 3                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 4                   2045600    GRADUAÇÃO  Campus Central  DNUT / Sala 1  2015
#
#       ...         tipo distancia        data_consolidacao agrupadora  \
# 0     ...      REGULAR         f                      NaN          f
# 1     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 2     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 3     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 4     ...      REGULAR         f  2015-06-19 10:28:09.708          f
#
#    id_turma_agrupadora  qtd_aulas_lancadas situacao_turma convenio  \
# 0                  NaN                 NaN       EXCLUÍDA      NaN
# 1                  NaN                34.0    CONSOLIDADA      NaN
# 2                  NaN                34.0    CONSOLIDADA      NaN
# 3                  NaN                34.0    CONSOLIDADA      NaN
# 4                  NaN                87.0    CONSOLIDADA      NaN
#
#   modalidade_participantes Unnamed: 25
# 0               Presencial         NaN
# 1               Presencial         NaN
# 2               Presencial         NaN
# 3               Presencial         NaN
# 4               Presencial         NaN
#
# [5 rows x 26 columns]

# %%
#Tipo de turmas
graduacao.tipo.unique()
# Out:
# array(['REGULAR', 'REPOSIÇÃO NO PERÍODO REGULAR', 'ENSINO INDIVIDUAL'],
#       dtype=object)

# %%
# Filtrando apenas turmas regulares
turmas = graduacao[graduacao.tipo == 'REGULAR']
turmas.reset_index(drop=True, inplace=True)
turmas.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0   1239272           01           5756213.0                 NaN        NaN
# 1   1239275           01           5757161.0                 NaN        NaN
# 2   1239275           01           1574976.0                 NaN        NaN
# 3   1239275           01             22932.0                 NaN        NaN
# 4   1239276           01           5752774.0                 NaN        NaN
#
#    id_componente_curricular nivel_ensino    campus_turma          local   ano  \
# 0                     52656    GRADUAÇÃO  Campus Central   B203 no CIVT  2015
# 1                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 2                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 3                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 4                   2045600    GRADUAÇÃO  Campus Central  DNUT / Sala 1  2015
#
#       ...         tipo distancia        data_consolidacao agrupadora  \
# 0     ...      REGULAR         f                      NaN          f
# 1     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 2     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 3     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 4     ...      REGULAR         f  2015-06-19 10:28:09.708          f
#
#    id_turma_agrupadora  qtd_aulas_lancadas situacao_turma convenio  \
# 0                  NaN                 NaN       EXCLUÍDA      NaN
# 1                  NaN                34.0    CONSOLIDADA      NaN
# 2                  NaN                34.0    CONSOLIDADA      NaN
# 3                  NaN                34.0    CONSOLIDADA      NaN
# 4                  NaN                87.0    CONSOLIDADA      NaN
#
#   modalidade_participantes Unnamed: 25
# 0               Presencial         NaN
# 1               Presencial         NaN
# 2               Presencial         NaN
# 3               Presencial         NaN
# 4               Presencial         NaN
#
# [5 rows x 26 columns]

# %%
#Verifica situações das turmas
turmas.situacao_turma.unique()
# Out:
# array(['EXCLUÍDA', 'CONSOLIDADA', 'INTERROMPIDA', 'ABERTA'], dtype=object)

# %%
#Filtrando apenas as turmas consolidadas

turmas_consolidadas = turmas[turmas.situacao_turma == 'CONSOLIDADA']
turmas_consolidadas.reset_index(drop=True, inplace=True)
turmas_consolidadas.head()
# Out:
#    id_turma codigo_turma  id_docente_interno  id_docente_externo observacao  \
# 0   1239275           01           5757161.0                 NaN        NaN
# 1   1239275           01           1574976.0                 NaN        NaN
# 2   1239275           01             22932.0                 NaN        NaN
# 3   1239276           01           5752774.0                 NaN        NaN
# 4   1239276           01           5757037.0                 NaN        NaN
#
#    id_componente_curricular nivel_ensino    campus_turma          local   ano  \
# 0                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 1                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 2                   2041854    GRADUAÇÃO  Campus Central  DNUT / Sala 2  2015
# 3                   2045600    GRADUAÇÃO  Campus Central  DNUT / Sala 1  2015
# 4                   2045600    GRADUAÇÃO  Campus Central  DNUT / Sala 1  2015
#
#       ...         tipo distancia        data_consolidacao agrupadora  \
# 0     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 1     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 2     ...      REGULAR         f  2015-06-23 09:49:33.375          f
# 3     ...      REGULAR         f  2015-06-19 10:28:09.708          f
# 4     ...      REGULAR         f  2015-06-19 10:28:09.708          f
#
#    id_turma_agrupadora  qtd_aulas_lancadas situacao_turma convenio  \
# 0                  NaN                34.0    CONSOLIDADA      NaN
# 1                  NaN                34.0    CONSOLIDADA      NaN
# 2                  NaN                34.0    CONSOLIDADA      NaN
# 3                  NaN                87.0    CONSOLIDADA      NaN
# 4                  NaN                87.0    CONSOLIDADA      NaN
#
#   modalidade_participantes Unnamed: 25
# 0               Presencial         NaN
# 1               Presencial         NaN
# 2               Presencial         NaN
# 3               Presencial         NaN
# 4               Presencial         NaN
#
# [5 rows x 26 columns]

# %%
# Exportando para CSV
turmas_consolidadas.to_csv("turmas.csv", sep=';')

# %%
# Lê CSV e converte para json
csvfile = pd.DataFrame(pd.read_csv("turmas.csv", sep = ";", header = 0, index_col = False))
csvfile.to_json("turmas.json", orient = "records", date_format = "epoch", double_precision = 10, force_ascii = True, date_unit = "ms", default_handler = None)
